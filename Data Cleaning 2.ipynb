# %%
import os
os.chdir("Data Sets")

# %%
import pandas as pd
pd.set_option('display.max_columns',None)
df = pd.read_csv("all_athlete_games.csv", low_memory=False)
sample = df[df["Year"]==2020] [["Entry ID","Name","Team","Sport","Event","Medal"]].head(12).reset_index(drop=True)
print(sample[["Name","Team","Sport","Event"]])
# Out:
#                  Name    Team                Sport  \
# 0     AALERUD Katrine  Norway         Cycling Road
# 1     AALERUD Katrine  Norway         Cycling Road
# 2         ABAD Nestor   Spain  Artistic Gymnastics
# 3         ABAD Nestor   Spain  Artistic Gymnastics
# 4         ABAD Nestor   Spain  Artistic Gymnastics
# 5         ABAD Nestor   Spain  Artistic Gymnastics
# 6         ABAD Nestor   Spain  Artistic Gymnastics
# 7         ABAD Nestor   Spain  Artistic Gymnastics
# 8         ABAD Nestor   Spain  Artistic Gymnastics
# 9         ABAD Nestor   Spain  Artistic Gymnastics
# 10  ABAGNALE Giovanni   Italy               Rowing
# 11     ABALDE Alberto   Spain           Basketball
#
#                             Event
# 0               Women's Road Race
# 1   Women's Individual Time Trial
# 2                Men's All-Around
# 3            Men's Floor Exercise
# 4              Men's Pommel Horse
# 5                     Men's Rings
# 6                     Men's Vault
# ...

# %% [markdown]
# # Duplicates

# %%
# Duplicates

# drop_duplicates(subset,keep)

# check with duplicated() first

# syntax - df.duplicated(subset=None,keep='first')

print(sample.duplicated())
print()
print(sample.duplicated(subset="Name"))
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# dtype: bool
#
# 0     False
# 1      True
# 2     False
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10    False
# 11    False
# dtype: bool

# %%
# Quick counting of duplicates

print(sample.duplicated(subset="Name").sum())

# Checking multiple columns at once

print(sample[sample.duplicated(subset=["Name","Sport"],keep="first")]
      [["Name","Sport","Event"]])
# Out:
# 8
#               Name                Sport                          Event
# 1  AALERUD Katrine         Cycling Road  Women's Individual Time Trial
# 3      ABAD Nestor  Artistic Gymnastics           Men's Floor Exercise
# 4      ABAD Nestor  Artistic Gymnastics             Men's Pommel Horse
# 5      ABAD Nestor  Artistic Gymnastics                    Men's Rings
# 6      ABAD Nestor  Artistic Gymnastics                    Men's Vault
# 7      ABAD Nestor  Artistic Gymnastics            Men's Parallel Bars
# 8      ABAD Nestor  Artistic Gymnastics           Men's Horizontal Bar
# 9      ABAD Nestor  Artistic Gymnastics                     Men's Team

# %% [markdown]
# | keep=          | Behavior                                              |
# |---------------------|--------------------------------------------------------------|
# | 'first' (default)       | Keep the first occurrence, drop later repeats                    |
# | 'last'                     | Keep the last occurrence, drop earlier repeats                     |
# | False                        | Drop EVERY row that has any duplicate at all                         |
