# %% [markdown]
# # Pandas - Dataframes, Series

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in C:\Users\Ramya\AppData\Roaming\Python\Python314\site-packages (3.0.3)
# Requirement already satisfied: numpy>=2.3.3 in C:\Users\Ramya\AppData\Roaming\Python\Python314\site-packages (from pandas) (2.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Ramya\AppData\Roaming\Python\Python314\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\Ramya\AppData\Roaming\Python\Python314\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\Ramya\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd

# Series Vs Dataframe

# Series
# syntax - 
# pd.series(data,index=None,name=None,dtype=None)

s = pd.Series([250,480,90,610], index = ["Mon","Tue","Wed","Thur"], name = "Daily Sales", dtype = float)
print(s)
print(type(s))
print(s.index)
print(s.values)

# A dictionary's keys become the index automatically
l = pd.Series({"Mon":250,"Tue":480,"Wed":90})
print(l)

# A scalar value broadcasts to every index label
h = pd.Series(5,index=["a","b","c"])
print(h)
# Out:
# Mon     250.0
# Tue     480.0
# Wed      90.0
# Thur    610.0
# Name: Daily Sales, dtype: float64
# <class 'pandas.Series'>
# Index(['Mon', 'Tue', 'Wed', 'Thur'], dtype='str')
# [250. 480.  90. 610.]
# Mon    250
# Tue    480
# Wed     90
# dtype: int64
# a    5
# b    5
# c    5
# dtype: int64

# %% [markdown]
# | Parameter | Used for                                              |
# |---------------|--------------------------------------------------------------|
# | data              | The values — a list, dict, or a single scalar (broadcasts)      |
# | index               | Custom labels for each value (defaults to 0,1,2...)                |
# | name                  | A label for the Series itself (becomes the column name later)          |
# | dtype                    | Force a specific data type                                                |

# %%
# DataFrame - 2D Table

# syntax - 
# pd.DataFrame(data,inex=None,columns=None,dtype=None)

# %% [markdown]
# | Parameter | Used for                                              |
# |---------------|--------------------------------------------------------------|
# | data              | A dict of lists (columns), list of dicts (rows), or list of lists |
# | index               | Custom row labels (defaults to 0,1,2...)                            |
# | columns               | Column names — REQUIRED if data is a list of lists                    |
# | dtype                    | Force a specific data type for all columns                              |

# %%
df = pd.DataFrame({"day":["Mon","Tue","Wed","Thur"],"sales":[250,480,90,610]})
print(df)
print(type(df))
# Out:
#     day  sales
# 0   Mon    250
# 1   Tue    480
# 2   Wed     90
# 3  Thur    610
# <class 'pandas.DataFrame'>
