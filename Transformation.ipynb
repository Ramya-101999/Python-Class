# %% [markdown]
# # Transformation

# %%
# Transformation - Data transformation using .map() - for dictionary substitution,
# .apply() for custom functions on rows and columns

# type conversion  - astype() and handling errors with pd.to_numeric(errors='coerce')

# %%
import os 
os.chdir("Data Sets")

# %%
import pandas as pd

df = pd.read_csv("all_athlete_games.csv", low_memory=False)
sample = df[df["Medal"].notna()][["Name","Gender","Age","NOC","Sport","Medal","Year"]].head(50).reset_index(drop=True)
print(sample)
# Out:
#                               Name Gender   Age  NOC          Sport   Medal  \
# 0                  Ioannis Andreou   Male   NaN  GRE       Swimming  Silver
# 1          Nikolaos Andriakopoulos   Male   NaN  GRE     Gymnastics    Gold
# 2                    Edward Battel   Male   NaN  GBR        Cycling  Bronze
# 3             Arthur Charles Blake   Male  24.0  USA      Athletics  Silver
# 4        Conrad Helmut Fritz Bcker   Male  25.0  GER     Gymnastics    Gold
# 5        Conrad Helmut Fritz Bcker   Male  25.0  GER     Gymnastics    Gold
# 6            John Mary Pius Boland   Male  25.0  GBR         Tennis    Gold
# 7            John Mary Pius Boland   Male  25.0  GBR         Tennis    Gold
# 8        Thomas Edmund "Tom" Burke   Male  21.0  USA      Athletics    Gold
# 9        Thomas Edmund "Tom" Burke   Male  21.0  USA      Athletics    Gold
# 10              Eugne Henri Callot   Male  20.0  FRA        Fencing  Silver
# 11     Demetrius Emmanuel Casdagli   Male  23.0  GRE         Tennis  Silver
# 12     Demetrius Emmanuel Casdagli   Male  23.0  GRE         Tennis  Silver
# 13            Ellery Harding Clark   Male  22.0  USA      Athletics    Gold
# 14            Ellery Harding Clark   Male  22.0  USA      Athletics    Gold
# 15   James Brendan Bennet Connolly   Male  27.0  USA      Athletics  Silver
# 16   James Brendan Bennet Connolly   Male  27.0  USA      Athletics  Bronze
# 17   James Brendan Bennet Connolly   Male  27.0  USA      Athletics    Gold
# 18      Thomas Pelham "Tom" Curtis   Male  23.0  USA      Athletics    Gold
# 19              Evangelos Damaskos   Male   NaN  GRE      Athletics  Bronze
# 20                       Nndor Dni   Male  24.0  HUN      Athletics  Silver
# 21                Nikolaos Dorakis   Male   NaN  GRE       Shooting  Bronze
# 22                Dimitrios Drivas   Male   NaN  GRE       Swimming  Bronze
# 23               Launceston Elliot   Male  21.0  GBR  Weightlifting    Gold
# 24               Launceston Elliot   Male  21.0  GBR  Weightlifting  Silver
# 25      Edwin Harold "Teddy" Flack   Male  22.0  AUS         Tennis  Bronze
# 26      Edwin Harold "Teddy" Flack   Male  22.0  AUS      Athletics    Gold
# 27      Edwin Harold "Teddy" Flack   Male  22.0  AUS      Athletics    Gold
# 28               Marie Lon Flameng   Male  18.0  FRA        Cycling  Bronze
# 29               Marie Lon Flameng   Male  18.0  FRA        Cycling  Silver
# 30               Marie Lon Flameng   Male  18.0  FRA        Cycling    Gold
# 31                   Alfred Flatow   Male  26.0  GER     Gymnastics    Gold
# 32                   Alfred Flatow   Male  26.0  GER     Gymnastics    Gold
# 33                   Alfred Flatow   Male  26.0  GER     Gymnastics  Silver
# 34                   Alfred Flatow   Male  26.0  GER     Gymnastics    Gold
# 35             Gustav Felix Flatow   Male  21.0  GER     Gymnastics    Gold
# 36             Gustav Felix Flatow   Male  21.0  GER     Gymnastics    Gold
# 37              Ioannis Frangoudis   Male   NaN  GRE       Shooting  Bronze
# 38              Ioannis Frangoudis   Male   NaN  GRE       Shooting    Gold
# 39              Ioannis Frangoudis   Male   NaN  GRE       Shooting  Silver
# 40            Robert "Bob" Garrett   Male  20.0  USA      Athletics  Silver
# 41            Robert "Bob" Garrett   Male  20.0  USA      Athletics  Silver
# 42            Robert "Bob" Garrett   Male  20.0  USA      Athletics    Gold
# 43            Robert "Bob" Garrett   Male  20.0  USA      Athletics    Gold
# 44              Ioannis Georgiadis   Male  20.0  GRE        Fencing    Gold
# 45     Charles Henry Stuart Gmelin   Male  23.0  GBR      Athletics  Bronze
# 46                    Anton Gdrich   Male  36.0  GER        Cycling  Silver
# 47            Dimitrios P. Golemis   Male  21.0  GRE      Athletics  Bronze
# 48  Grantley Thomas Smart Goulding   Male  22.0  GBR      Athletics  Silver
# 49               Miltiadis Gouskos   Male   NaN  GRE      Athletics  Silver
#
#     Year
# 0   1896
# 1   1896
# 2   1896
# 3   1896
# 4   1896
# 5   1896
# 6   1896
# 7   1896
# 8   1896
# 9   1896
# 10  1896
# 11  1896
# 12  1896
# 13  1896
# 14  1896
# 15  1896
# 16  1896
# 17  1896
# 18  1896
# 19  1896
# 20  1896
# 21  1896
# 22  1896
# 23  1896
# 24  1896
# 25  1896
# 26  1896
# 27  1896
# 28  1896
# 29  1896
# 30  1896
# 31  1896
# 32  1896
# 33  1896
# 34  1896
# 35  1896
# 36  1896
# 37  1896
# 38  1896
# 39  1896
# 40  1896
# 41  1896
# 42  1896
# 43  1896
# 44  1896
# 45  1896
# 46  1896
# 47  1896
# 48  1896
# 49  1896

# %%
# mapping, .map() for dictionary substitution

#syntax - series.map(dict/function)

#where mapping is a dict or a funtion

points_map = {"Gold":3,"Silver":2,"Bronze":1}
print(sample["Medal"].map(points_map))
print(sample["Medal"])

gender_map = {"Male":"M"}
print(sample["Gender"].map(gender_map))
print(sample["Gender"])
# Out:
# 0    3
# 1    2
# 2    3
# 3    1
# 4    1
# 5    1
# 6    3
# 7    2
# Name: Medal, dtype: int64
# 0      Gold
# 1    Silver
# 2      Gold
# 3    Bronze
# 4    Bronze
# 5    Bronze
# 6      Gold
# 7    Silver
# Name: Medal, dtype: str
# 0      M
# 1    NaN
# 2    NaN
# 3      M
# 4      M
# 5      M
# 6      M
# 7      M
# Name: Gender, dtype: str
# 0      Male
# 1    Female
# 2    Female
# 3      Male
# 4      Male
# 5      Male
# 6      Male
# 7      Male
# Name: Gender, dtype: str

# %%
# mapping with a function instead of a dict

print(sample["Medal"].map(len))
# Out:
# 0    4
# 1    6
# 2    4
# 3    6
# 4    6
# 5    6
# 6    4
# 7    6
# Name: Medal, dtype: int64

# %%
# veteran if age>=30 else young 

print(sample["Age"].map(lambda a:"Veteran" if a>=30 else "Young"))
# Out:
# 0    Veteran
# 1    Veteran
# 2      Young
# 3    Veteran
# 4      Young
# 5    Veteran
# 6      Young
# 7      Young
# Name: Age, dtype: str

# %%
# .apply()

# for applying custom on rows/columns

# syntax - series.apply(function)

# df.apply(function,axis=0 or 1)

# .apply on a single column(series)

print(sample["Age"].apply(lambda a:round(a*10)))
# Out:
# 0    360
# 1    360
# 2    220
# 3    320
# 4    200
# 5    310
# 6    230
# 7    230
# Name: Age, dtype: int64

# %%
# row wise apply on a dataframe

def summarize(row):
    return f"{row["Name"]}({row["NOC"]}) won {row["Medal"]} in {row["Sport"]}"

print(sample.apply(summarize,axis=1))

print()

# column-wise apply (default method)

print(sample[["Age"]].apply(lambda col:col.max()-col.min()))
# Out:
# 0                  ABALO Luc(FRA) won Gold in Handball
# 1    ABBOTT Monica(USA) won Silver in Baseball/Soft...
# 2             ABDELAZIZ Feryal(EGY) won Gold in Karate
# 3             ABDI Bashir(BEL) won Bronze in Athletics
# 4    ABDULLAH Rahmat Erwin(INA) won Bronze in Weigh...
# 5    ABDURAKHMONOV Bekzod(UZB) won Bronze in Wrestling
# 6                     ABE Hifumi(JPN) won Gold in Judo
# 7                   ABE Hifumi(JPN) won Silver in Judo
# dtype: str
#
# Age    16.0
# dtype: float64

# %% [markdown]
# | Call                          | What gets passed to your function              |
# |------------------------------------|--------------------------------------------------------|
# | series.apply(func)                     | Each individual VALUE, one at a time                       |
# | df.apply(func, axis=0)  (default)         | Each entire COLUMN, one at a time                             |
# | df.apply(func, axis=1)                       | Each entire ROW, one at a time — access fields by row["col"]     |

# %% [markdown]
# # Type Conversion

# %%
# Type conversion - astype()

# and pd.to_numeric(errors='coerce')

# astype() - straight forward conversion when data is already clean

print(sample["Age"])
