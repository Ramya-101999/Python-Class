# %% [markdown]
# # Logic Basics

# %%
# Data Type conversion
a = 5
b = "5"
c = 5.5
d = "hello"
e = None
f = True

# Type Conversion
# Integer datatype ----> float,str,bool
g= float(a)
print(type(a))
print(a)
print(type(g))
print(g)

h = str(a)
print(type(h))
print(h)

i = bool(a)
print(type(i))
# Out:
# <class 'int'>
# 5
# <class 'float'>
# 5.0
# <class 'str'>
# 5
# <class 'bool'>
